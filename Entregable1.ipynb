# %% [markdown]
# <a href="https://colab.research.google.com/github/Victor091299/CDP-PROYECYO03/blob/main/Entregable1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# instalamos
# !pip install statistics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#cargamos las librerias
import pandas as pd
import seaborn as sns
import statistics as stats # estadística
import numpy as np
import scipy

import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d10d9406-22cd-4600-a060-0812a13f0b91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d10d9406-22cd-4600-a060-0812a13f0b91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data_Nutricion_grupos.xlsx to Data_Nutricion_grupos.xlsx
# ...

# %%
#CONVERTIMOS LA DATA EN UN DATAFRAME Y LA ALMACENAMOS EN UN IDENTIFICADOR
datos_nutricion=pd.read_excel('Data_Nutricion_grupos.xlsx')
#MOSTRAMOS LOS PRIMEROS REGISTROS DE MI DATAFRAMAE
datos_nutricion.head()
# Out:
#    Individuo  talla  edad  peso_kg  circun_cuello        IMC  circun_cintura  \
# 0  Persona 1  155.7  16.0     71.2           35.7  29.576170            90.0
# 1  Persona 2  166.5  16.0     61.0           31.8  22.364707            80.9
# 2  Persona 3  151.3  16.0     49.1           30.5  21.623567            72.0
# 3  Persona 4  151.7  16.0     54.6           32.6  23.117479             NaN
# 4  Persona 5  160.3  16.0     58.0           30.1  22.260196             NaN
#
#    cadera  ind_cintura_cadera  ind_cintura_estatura  por_grasa_corporal  \
# 0    98.0            0.918367              0.578035           36.446202
# 1   100.5            0.804975              0.485886           28.790714
# 2    86.0            0.837209              0.475876           29.867419
# 3    88.4            0.841629              0.490442           27.867640
# 4    97.9            0.813075                   NaN           30.276688
#
# ...

# %%
# VERIFICANDO LA FORMA DE MI DATAFRAME
datos_nutricion.shape
# Out:
# (652, 17)

# %%
#OTRA MANERA DE VERIFICAR CUANTAS FILAS Y COLUMAS TIENE MI DATAFRAME
print("La cantidad de columnas en mi dataframe es: ",datos_nutricion.shape[1])
print("La cantidad de filas en mi dataframe es: ",datos_nutricion.shape[0])
# Out:
# La cantidad de columnas en mi dataframe es:  17
# La cantidad de filas en mi dataframe es:  652

# %%
#VERIFICANDO LA INFORMACION DE MI DATAFRAME
datos_nutricion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Individuo                    652 non-null    object
#  1   talla                        624 non-null    float64
#  2   edad                         645 non-null    float64
#  3   peso_kg                      629 non-null    float64
#  4   circun_cuello                623 non-null    float64
#  5   IMC                          640 non-null    float64
#  6   circun_cintura               637 non-null    float64
#  7   cadera                       647 non-null    float64
#  8   ind_cintura_cadera           639 non-null    float64
#  9   ind_cintura_estatura         636 non-null    float64
#  10  por_grasa_corporal           650 non-null    float64
#  11  masa_corporal_magra_kg       648 non-null    float64
# ...

# %%
#VERIFICANDO SI EXISTEN DATOS PERDIDOS O NULOS EN MIS VARIABLES
datos_nutricion.isnull().sum()
# Out:
# Individuo                       0
# talla                          28
# edad                            7
# peso_kg                        23
# circun_cuello                  29
# IMC                            12
# circun_cintura                 15
# cadera                          5
# ind_cintura_cadera             13
# ind_cintura_estatura           16
# por_grasa_corporal              2
# masa_corporal_magra_kg          4
# pliegue_cutaneo_BICEPS          0
# pliegue_cutaneo_TRICEPS         0
# pliegue_cutaneo_ESCAPULAR       0
# pliegue_cutaneo_SUPRAILIACO     0
# Grupos                          0
# dtype: int64

# %%
#REMPLAZANDO LOS DATOS PERDIDOS O NULOS POR LA MEDIA DE CADA VARIABLE DE MI DATAFRAME
datos_nutricion.fillna(datos_nutricion.mean(),inplace=True)
datos_nutricion.round(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#        Individuo  talla  edad  peso_kg  circun_cuello    IMC  circun_cintura  \
# 0      Persona 1  155.7  16.0     71.2           35.7  29.58           90.00
# 1      Persona 2  166.5  16.0     61.0           31.8  22.36           80.90
# 2      Persona 3  151.3  16.0     49.1           30.5  21.62           72.00
# 3      Persona 4  151.7  16.0     54.6           32.6  23.12           74.52
# 4      Persona 5  160.3  16.0     58.0           30.1  22.26           74.52
# ..           ...    ...   ...      ...            ...    ...             ...
# 647  Persona 648  165.5  14.0     88.0           32.5  21.03           72.50
# 648  Persona 649  144.2  14.0     48.6           31.5  23.13           73.00
# ...

# %%
#VERIFICAMOS SU NUESTRA VARIABLE MAS IMPORTANTE CUENTA CON DATOS DUPLICADOS
datos_nutricion[datos_nutricion["Individuo"].duplicated()].head()
# Out:
# Empty DataFrame
# Columns: [Individuo, talla, edad, peso_kg, circun_cuello, IMC, circun_cintura, cadera, ind_cintura_cadera, ind_cintura_estatura, por_grasa_corporal, masa_corporal_magra_kg, pliegue_cutaneo_BICEPS, pliegue_cutaneo_TRICEPS, pliegue_cutaneo_ESCAPULAR, pliegue_cutaneo_SUPRAILIACO, Grupos]
# Index: []

# %%
#CAMBIANDO DE TIPO DE VARIABLE DE FLOAT A INT
datos_nutricion["edad"]=datos_nutricion["edad"].astype(int)
datos_nutricion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Individuo                    652 non-null    object
#  1   talla                        652 non-null    float64
#  2   edad                         652 non-null    int64
#  3   peso_kg                      652 non-null    float64
#  4   circun_cuello                652 non-null    float64
#  5   IMC                          652 non-null    float64
#  6   circun_cintura               652 non-null    float64
#  7   cadera                       652 non-null    float64
#  8   ind_cintura_cadera           652 non-null    float64
#  9   ind_cintura_estatura         652 non-null    float64
#  10  por_grasa_corporal           652 non-null    float64
#  11  masa_corporal_magra_kg       652 non-null    float64
# ...

# %%
#CAMBIANDO DE TIPO DE VARIABLE DE FLOAT A INT
datos_nutricion["peso_kg"]=datos_nutricion["peso_kg"].astype(int)
datos_nutricion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Individuo                    652 non-null    object
#  1   talla                        652 non-null    float64
#  2   edad                         652 non-null    int64
#  3   peso_kg                      652 non-null    int64
#  4   circun_cuello                652 non-null    float64
#  5   IMC                          652 non-null    float64
#  6   circun_cintura               652 non-null    float64
#  7   cadera                       652 non-null    float64
#  8   ind_cintura_cadera           652 non-null    float64
#  9   ind_cintura_estatura         652 non-null    float64
#  10  por_grasa_corporal           652 non-null    float64
#  11  masa_corporal_magra_kg       652 non-null    float64
# ...

# %%
#CAMBIANDO DE TIPO DE VARIABLE DE FLOAT A INT
datos_nutricion["talla"]=datos_nutricion["talla"].astype(int)
datos_nutricion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Individuo                    652 non-null    object
#  1   talla                        652 non-null    int64
#  2   edad                         652 non-null    int64
#  3   peso_kg                      652 non-null    int64
#  4   circun_cuello                652 non-null    float64
#  5   IMC                          652 non-null    float64
#  6   circun_cintura               652 non-null    float64
#  7   cadera                       652 non-null    float64
#  8   ind_cintura_cadera           652 non-null    float64
#  9   ind_cintura_estatura         652 non-null    float64
#  10  por_grasa_corporal           652 non-null    float64
#  11  masa_corporal_magra_kg       652 non-null    float64
#  12  pliegue_cutaneo_BICEPS       652 non-null    float64
# ...

# %%
#CAMBIANDO DE TIPO DE VARIABLE DE FLOAT A INT
datos_nutricion["circun_cuello"]=datos_nutricion["circun_cuello"].astype(int)
datos_nutricion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Individuo                    652 non-null    object
#  1   talla                        652 non-null    int64
#  2   edad                         652 non-null    int64
#  3   peso_kg                      652 non-null    int64
#  4   circun_cuello                652 non-null    int64
#  5   IMC                          652 non-null    float64
#  6   circun_cintura               652 non-null    float64
#  7   cadera                       652 non-null    float64
#  8   ind_cintura_cadera           652 non-null    float64
#  9   ind_cintura_estatura         652 non-null    float64
#  10  por_grasa_corporal           652 non-null    float64
#  11  masa_corporal_magra_kg       652 non-null    float64
#  12  pliegue_cutaneo_BICEPS       652 non-null    float64
# ...

# %%
#CAMBIANDO DE TIPO DE VARIABLE DE FLOAT A INT
datos_nutricion["IMC"]=datos_nutricion["IMC"].astype(int)
datos_nutricion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Individuo                    652 non-null    object
#  1   talla                        652 non-null    int64
#  2   edad                         652 non-null    int64
#  3   peso_kg                      652 non-null    int64
#  4   circun_cuello                652 non-null    int64
#  5   IMC                          652 non-null    int64
#  6   circun_cintura               652 non-null    float64
#  7   cadera                       652 non-null    float64
#  8   ind_cintura_cadera           652 non-null    float64
#  9   ind_cintura_estatura         652 non-null    float64
#  10  por_grasa_corporal           652 non-null    float64
#  11  masa_corporal_magra_kg       652 non-null    float64
#  12  pliegue_cutaneo_BICEPS       652 non-null    float64
# ...

# %%
#CAMBIANDO DE TIPO DE VARIABLE DE FLOAT A INT
datos_nutricion["circun_cintura"]=datos_nutricion["circun_cintura"].astype(int)
datos_nutricion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Individuo                    652 non-null    object
#  1   talla                        652 non-null    int64
#  2   edad                         652 non-null    int64
#  3   peso_kg                      652 non-null    int64
#  4   circun_cuello                652 non-null    int64
#  5   IMC                          652 non-null    int64
#  6   circun_cintura               652 non-null    int64
#  7   cadera                       652 non-null    float64
#  8   ind_cintura_cadera           652 non-null    float64
#  9   ind_cintura_estatura         652 non-null    float64
#  10  por_grasa_corporal           652 non-null    float64
#  11  masa_corporal_magra_kg       652 non-null    float64
#  12  pliegue_cutaneo_BICEPS       652 non-null    float64
# ...

# %%
#CAMBIANDO DE TIPO DE VARIABLE DE FLOAT A INT
datos_nutricion["cadera"]=datos_nutricion["cadera"].astype(int)
datos_nutricion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Individuo                    652 non-null    object
#  1   talla                        652 non-null    int64
#  2   edad                         652 non-null    int64
#  3   peso_kg                      652 non-null    int64
#  4   circun_cuello                652 non-null    int64
#  5   IMC                          652 non-null    int64
#  6   circun_cintura               652 non-null    int64
#  7   cadera                       652 non-null    int64
#  8   ind_cintura_cadera           652 non-null    float64
#  9   ind_cintura_estatura         652 non-null    float64
#  10  por_grasa_corporal           652 non-null    float64
#  11  masa_corporal_magra_kg       652 non-null    float64
#  12  pliegue_cutaneo_BICEPS       652 non-null    float64
# ...

# %% [markdown]
# ---
#
#
# SELECCIONANDO SOLO LAS COLUMNAS CUALITATIVAS Y CUANTITATIVAS

# %%
#SELECCIONANDO COLUMNAS CUALITATIVAS
var_str=datos_nutricion.select_dtypes(exclude=['float64','int']).columns
datos_nutricion[var_str].head()
# Out:
#    Individuo Grupos
# 0  Persona 1      A
# 1  Persona 2      A
# 2  Persona 3      A
# 3  Persona 4      A
# 4  Persona 5      A

# %%
#SELECCIONANDO SOLO LAS COMUMNAS CUANTITATIVAS
var_num=datos_nutricion.select_dtypes(include=['float64','int']).columns
datos_nutricion[var_num].round(2).head()
# Out:
#    talla  edad  peso_kg  circun_cuello  IMC  circun_cintura  cadera  \
# 0    155    16       71             35   29              90      98
# 1    166    16       61             31   22              80     100
# 2    151    16       49             30   21              72      86
# 3    151    16       54             32   23              74      88
# 4    160    16       58             30   22              74      97
#
#    ind_cintura_cadera  ind_cintura_estatura  por_grasa_corporal  \
# 0                0.92                  0.58               36.45
# 1                0.80                  0.49               28.79
# 2                0.84                  0.48               29.87
# 3                0.84                  0.49               27.87
# 4                0.81                  0.47               30.28
#
#    masa_corporal_magra_kg  pliegue_cutaneo_BICEPS  pliegue_cutaneo_TRICEPS  \
# 0                   45.25                    13.0                     27.0
# ...

# %%
#OBTENIENDO LA MEDIA DE LAS VARIABLES DE MI DATAFRAME
datos_nutricion[var_num].mean().round(2)
# Out:
# talla                          158.39
# edad                            14.75
# peso_kg                         56.50
# circun_cuello                   31.72
# IMC                             21.93
# circun_cintura                  74.28
# cadera                          89.60
# ind_cintura_cadera               0.83
# ind_cintura_estatura             0.47
# por_grasa_corporal              23.54
# masa_corporal_magra_kg          43.38
# pliegue_cutaneo_BICEPS           9.18
# pliegue_cutaneo_TRICEPS         15.65
# pliegue_cutaneo_ESCAPULAR       14.38
# pliegue_cutaneo_SUPRAILIACO     14.68
# dtype: float64

# %%
#OBTENIENDO LA MEDIANA DE LAS VARIABLES DE MI DATAFRAME
datos_nutricion.median().round(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# talla                          158.00
# edad                            15.00
# peso_kg                         56.00
# circun_cuello                   32.00
# IMC                             22.00
# circun_cintura                  73.50
# cadera                          89.00
# ind_cintura_cadera               0.83
# ind_cintura_estatura             0.47
# por_grasa_corporal              26.09
# masa_corporal_magra_kg          42.37
# pliegue_cutaneo_BICEPS           8.00
# pliegue_cutaneo_TRICEPS         16.00
# pliegue_cutaneo_ESCAPULAR       14.00
# pliegue_cutaneo_SUPRAILIACO     15.00
# dtype: float64

# %% [markdown]
# OBTENIENDO MEDIA A TRAVEZ DE UNA FUNCION

# %%
#CREANDO LA FUNCION LLAMADA MEDIA 
def media(x):
  '''
  NOS RETORNARÁ EL PROMEDIO DE CADA VARIBALE
  '''
  return stats.mean(x)

# %%
#APLICANDO LA FUNCION MEDIA A LAS VARIABLE NUMERICAS DE MI DATAFRAME
datos_nutricion[var_num].apply(media,axis=0).round(2)
# Out:
# talla                          158.39
# edad                            14.75
# peso_kg                         56.50
# circun_cuello                   31.72
# IMC                             21.93
# circun_cintura                  74.28
# cadera                          89.60
# ind_cintura_cadera               0.83
# ind_cintura_estatura             0.47
# por_grasa_corporal              23.54
# masa_corporal_magra_kg          43.38
# pliegue_cutaneo_BICEPS           9.18
# pliegue_cutaneo_TRICEPS         15.65
# pliegue_cutaneo_ESCAPULAR       14.38
# pliegue_cutaneo_SUPRAILIACO     14.68
# dtype: float64

# %% [markdown]
# OBTENIENDO LA MEDIANA A TRAVEZ DE UNA FUNCION

# %%
#CREANDO LA FUNCION LLAMADA MEDIANA 
def mediana(x):
  '''
  NOS DARÁ EL VALOR QUE OCUPA LA POSICION CENTRAL DE CADA VARIABLE
  '''
  return stats.median(x)

# %%
#APLICANDO LA FUNCION MEDIANA A LAS VARIABLES NUMERICAS DE MI DATAFRAME
datos_nutricion[var_num].apply(mediana,axis=0).round(2)
# Out:
# talla                          158.00
# edad                            15.00
# peso_kg                         56.00
# circun_cuello                   32.00
# IMC                             22.00
# circun_cintura                  73.50
# cadera                          89.00
# ind_cintura_cadera               0.83
# ind_cintura_estatura             0.47
# por_grasa_corporal              26.09
# masa_corporal_magra_kg          42.37
# pliegue_cutaneo_BICEPS           8.00
# pliegue_cutaneo_TRICEPS         16.00
# pliegue_cutaneo_ESCAPULAR       14.00
# pliegue_cutaneo_SUPRAILIACO     15.00
# dtype: float64

# %% [markdown]
# OBTENIENDO LA MODA A TRAVEZ DE UNA FUNCION

# %%
#CREANDO LA FUNCION LLAMADA MODA
#DE COLLECTIONS IMPORTAMOS LA LIBRERIA COUNTER QUE NOS AYUDARA A CONTAR LA CANTIDAD DE ELEMENTOS DE CADA VARIABLE
from collections import Counter

def moda(x):
  '''
  NOS RETORNARÁ EL VALOR QUE MAS SE REPITE POR VARIABLE Y EL NUMERO DE VECES QUE SE REPITE
  '''
  c=Counter(x) #LA CANTIDAD DE ELEMENTOS DE CADA VARIABLE SE ALAMACENARÁ EN EL IDENTIFICADOR "C"
  return c.most_common(1) #A "C" SE LE APLICARÁ LA FUNCION MOS_COMON QUE NOS RETORNARÁ EL VALOR MAS REPETIDO Y LA CANTIDAD DE VECES QUE SE REPITE.

# %%
#APLICANDO LA FUNCION MODA A LAS VARIABLES NUMERICAS DE MI DATAFRAME
datos_nutricion[var_num].apply(moda,axis=0)
# Out:
#        talla       edad   peso_kg circun_cuello        IMC circun_cintura  \
# 0  (158, 54)  (14, 252)  (56, 59)     (32, 141)  (22, 106)       (74, 49)
#
#      cadera        ind_cintura_cadera       ind_cintura_estatura  \
# 0  (86, 45)  (0.8310482405969504, 13)  (0.47061744398984784, 16)
#
#          por_grasa_corporal  masa_corporal_magra_kg pliegue_cutaneo_BICEPS  \
# 0  (28.790714086448155, 18)  (43.37947584941732, 4)              (5.0, 82)
#
#   pliegue_cutaneo_TRICEPS pliegue_cutaneo_ESCAPULAR  \
# 0              (18.0, 53)                (10.0, 61)
#
#   pliegue_cutaneo_SUPRAILIACO
# 0                  (18.0, 49)

# %% [markdown]
# OBTENIENDO EL CENTRO DE AMPLITUD A TRAVEZ DE UNA FUNCION

# %%
#CREANDO LA FUNCION LLAMADA CENTRO DE AMPLITUD
def centro_apli(x):
  '''
  COMO RESULTADO NOS DARÁ EL VALOR MEDIO ENTRE EL MINIMO Y MAXIMO 
  '''
  return (max(x) - min(x))/2

# %%
#APLICANDO LA FUNCION CENTRO_AMPLI A LAS VARIABLES NUMERICAS DE MI DATAFRAME
datos_nutricion[var_num].apply(centro_apli,axis=0).round(2)
# Out:
# talla                          26.50
# edad                            8.50
# peso_kg                        29.00
# circun_cuello                   7.50
# IMC                            11.00
# circun_cintura                 26.00
# cadera                         25.50
# ind_cintura_cadera              0.19
# ind_cintura_estatura            0.17
# por_grasa_corporal             17.62
# masa_corporal_magra_kg         21.54
# pliegue_cutaneo_BICEPS         44.00
# pliegue_cutaneo_TRICEPS        17.00
# pliegue_cutaneo_ESCAPULAR      15.00
# pliegue_cutaneo_SUPRAILIACO    16.00
# dtype: float64

# %% [markdown]
# OBTENIENDO LA MEDIA GEOMETRICA A TRAVEZ DE UNA FUNCION

# %%
#CREANDO LA FUNCION LLAMADA MEDIA GEOMETRICA
def med_geome(iterable):
  '''
  REALIZA EL CALCULO DE LA MEDIA GEOMETRICA

  MULTIPLICARÁ LOS ELEMENTOS DE CADA VARIABLE PARA LUEGO CALCULAR LA RAIZ CON EL EXPONENTE N(n° DE ELEMENTO DE LA VARIABLE)
  '''
  a=np.log(iterable)
  return "Media Geometrica",np.exp(a.sum()/len(a)).round(2)

# %%
#APLICANDO LA FUNCION MED_GEOME
datos_nutricion[var_num].apply(med_geome,axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#               talla              edad           peso_kg     circun_cuello  \
# 0  Media Geometrica  Media Geometrica  Media Geometrica  Media Geometrica
# 1            158.22               0.0              55.9             31.65
#
#                 IMC    circun_cintura            cadera ind_cintura_cadera  \
# 0  Media Geometrica  Media Geometrica  Media Geometrica   Media Geometrica
# 1             21.73             73.98             89.33               0.83
#
#   ind_cintura_estatura por_grasa_corporal masa_corporal_magra_kg  \
# 0     Media Geometrica   Media Geometrica       Media Geometrica
# 1                 0.47              21.94                  42.85
#
#   pliegue_cutaneo_BICEPS pliegue_cutaneo_TRICEPS pliegue_cutaneo_ESCAPULAR  \
# ...

# %% [markdown]
# OBTENIENDO LA MEDIA ARMONICA A TRAVEZ DE UNA FUNCION

# %%
#CREANDO LA FUNCION LLAMADA MEDIA ARMONICA
def media_armonica(x):
  return "Media Armonica", round(stats.harmonic_mean(x),2)

# %%
datos_nutricion[var_num].apply(media_armonica,axis=0)
# Out:
#             talla            edad         peso_kg   circun_cuello  \
# 0  Media Armonica  Media Armonica  Media Armonica  Media Armonica
# 1          158.06               0           55.32           31.58
#
#               IMC  circun_cintura          cadera ind_cintura_cadera  \
# 0  Media Armonica  Media Armonica  Media Armonica     Media Armonica
# 1           21.53           73.69           89.06               0.83
#
#   ind_cintura_estatura por_grasa_corporal masa_corporal_magra_kg  \
# 0       Media Armonica     Media Armonica         Media Armonica
# 1                 0.47              20.02                  42.34
#
#   pliegue_cutaneo_BICEPS pliegue_cutaneo_TRICEPS pliegue_cutaneo_ESCAPULAR  \
# 0         Media Armonica          Media Armonica            Media Armonica
# 1                   6.86                   13.37                     12.53
#
#   pliegue_cutaneo_SUPRAILIACO
# 0              Media Armonica
# 1                       11.94

# %% [markdown]
# MEDIDAS DE DISPERSION

# %%
#RANGO
#CREANDO LA FUNCION LLAMADA RANGO

def rango(x):
  '''
  RESTARÁ EL MINIMO Y MAXIMO VALOR
  DE UN CONJUNTO DE ELEMENTOS

  COMO RESULTADO NOS DARÁ EL RANGO
  '''
  min=np.min(x)
  max=np.max(x)
  r= max - min
  return min,max,r

# %%
#APLICANDO LA FUNCION RANGO A LAS VARIABLES NUMERICAS DE MI DATAFRAME
p=datos_nutricion[var_num].apply(rango,axis=0).round(2).T
p.columns=["Minimo","Maximo","Rango"]
p
# Out:
#                              Minimo  Maximo  Rango
# talla                        135.00  188.00  53.00
# edad                           0.00   17.00  17.00
# peso_kg                       33.00   91.00  58.00
# circun_cuello                 24.00   39.00  15.00
# IMC                           14.00   36.00  22.00
# circun_cintura                55.00  107.00  52.00
# cadera                        69.00  120.00  51.00
# ind_cintura_cadera             0.65    1.03   0.37
# ind_cintura_estatura           0.36    0.70   0.34
# por_grasa_corporal             4.21   39.45  35.23
# masa_corporal_magra_kg        28.50   71.57  43.07
# pliegue_cutaneo_BICEPS         2.00   90.00  88.00
# pliegue_cutaneo_TRICEPS        5.00   39.00  34.00
# pliegue_cutaneo_ESCAPULAR      5.00   35.00  30.00
# pliegue_cutaneo_SUPRAILIACO    3.00   35.00  32.00

# %%
#CUARTILES
#CREANDO FUNCION LLAMADA CUARTILES
def cuartiles(x: pd.Series):
    '''
    Nos retornará como resultado los cuariles 
    25,50,75 y los valores min y max 
    '''
    Q1 = x.quantile([.25]).values[0]
    Q2 = x.quantile([.50]).values[0]
    Q3 = x.quantile([.75]).values[0]
    min = np.min(x)
    max = np.max(x)
    return min, Q1, Q2, Q3, max

# %%
#APLICANDO LA FUNCION LLAMADA CUARTILES
j = datos_nutricion[var_num].apply(cuartiles, axis=0).round(2).T
j.columns = ["Mínimo","P25% - Q1","P50% - Q2", "P75% - Q3", "Máximo"]
j
# Out:
#                              Mínimo  P25% - Q1  P50% - Q2  P75% - Q3  Máximo
# talla                        135.00     153.00     158.00     163.00  188.00
# edad                           0.00      14.00      15.00      15.00   17.00
# peso_kg                       33.00      51.00      56.00      61.00   91.00
# circun_cuello                 24.00      30.00      32.00      33.00   39.00
# IMC                           14.00      20.00      22.00      23.00   36.00
# circun_cintura                55.00      70.00      73.50      78.00  107.00
# cadera                        69.00      85.00      89.00      94.00  120.00
# ind_cintura_cadera             0.65       0.80       0.83       0.87    1.03
# ind_cintura_estatura           0.36       0.44       0.47       0.49    0.70
# por_grasa_corporal             4.21      16.13      26.09      30.07   39.45
# masa_corporal_magra_kg        28.50      38.16      42.37      48.06   71.57
# ...

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(6, 3.84))

g=sns.boxplot(
        x     = 'Grupos',  # variable cualitativa
        y     = 'talla',  # variable cuantitativa
        data  = datos_nutricion,   # dataframe
        ax    = ax
    )

g.set_xlabel("Grupos")
g.set_ylabel("talla")
g.set_title("Gráfico Nº XX: Score según la talla")
# Out:
# Text(0.5, 1.0, 'Gráfico Nº XX: Score según la talla')

# %%
#RANGO INTERCUARTIL
#CREANDO LA FUNCION LLAMADA RANGO INTERCUARTIL
def rango_intercuartil(x: pd.Series):
    '''
    NOS RETORNARÁ EL CUARTIL 25,75 Y EL 
    RANGO INTERCUARTIL
    '''
    Q1 = x.quantile([.25]).values[0]
    Q3 = x.quantile([.75]).values[0]

    return Q1, Q3 - Q1, Q3

# %%
#APLICANDO LA FUNCION LLAMADA RANGO INTERCUARTIL
o=datos_nutricion[var_num].apply(rango_intercuartil, axis=0).T
o.columns = ["Q1","RIC","Q3"]
o
# Out:
#                                      Q1        RIC          Q3
# talla                        153.000000  10.000000  163.000000
# edad                          14.000000   1.000000   15.000000
# peso_kg                       51.000000  10.000000   61.000000
# circun_cuello                 30.000000   3.000000   33.000000
# IMC                           20.000000   3.000000   23.000000
# circun_cintura                70.000000   8.000000   78.000000
# cadera                        85.000000   9.000000   94.000000
# ind_cintura_cadera             0.795298   0.071369    0.866667
# ind_cintura_estatura           0.439406   0.054204    0.493610
# por_grasa_corporal            16.127803  13.945690   30.073493
# masa_corporal_magra_kg        38.164889   9.899905   48.064794
# pliegue_cutaneo_BICEPS         5.000000   7.000000   12.000000
# pliegue_cutaneo_TRICEPS       11.000000   8.000000   19.000000
# pliegue_cutaneo_ESCAPULAR     10.000000   8.000000   18.000000
# ...

# %%
#VARIANZA
import numpy as np
#CON np.var se calculará la varianza para cada una de mis variables numericas
datos_nutricion[var_num].apply(np.var, axis=0).round(2)
# Out:
# talla                          53.78
# edad                            1.10
# peso_kg                        71.30
# circun_cuello                   4.54
# IMC                             9.25
# circun_cintura                 46.42
# cadera                         50.95
# ind_cintura_cadera              0.00
# ind_cintura_estatura            0.00
# por_grasa_corporal             61.51
# masa_corporal_magra_kg         47.64
# pliegue_cutaneo_BICEPS         32.01
# pliegue_cutaneo_TRICEPS        32.36
# pliegue_cutaneo_ESCAPULAR      28.13
# pliegue_cutaneo_SUPRAILIACO    35.39
# dtype: float64

# %%
#DESVIACION ESTANDAR
datos_nutricion[var_num].apply(np.std, axis=0).round(2)
# Out:
# talla                          7.33
# edad                           1.05
# peso_kg                        8.44
# circun_cuello                  2.13
# IMC                            3.04
# circun_cintura                 6.81
# cadera                         7.14
# ind_cintura_cadera             0.05
# ind_cintura_estatura           0.05
# por_grasa_corporal             7.84
# masa_corporal_magra_kg         6.90
# pliegue_cutaneo_BICEPS         5.66
# pliegue_cutaneo_TRICEPS        5.69
# pliegue_cutaneo_ESCAPULAR      5.30
# pliegue_cutaneo_SUPRAILIACO    5.95
# dtype: float64

# %%
#COEFICIENTE DE VARIACION 
def coeficiente_variacion(x):
  m = stats.mean(x)
  sd = np.std(x)
  return sd/m*100

# %%
#APLICANDO LA FUNCION LLAMADA COEFICIENTE DE VARIACION
datos_nutricion[var_num].apply(coeficiente_variacion, axis=0).round(2), "Porciento %"
# Out:
# (talla                           4.63
#  edad                            7.13
#  peso_kg                        14.95
#  circun_cuello                   6.72
#  IMC                            13.87
#  circun_cintura                  9.17
#  cadera                          7.97
#  ind_cintura_cadera              6.51
#  ind_cintura_estatura            9.74
#  por_grasa_corporal             33.32
#  masa_corporal_magra_kg         15.91
#  pliegue_cutaneo_BICEPS         61.62
#  pliegue_cutaneo_TRICEPS        36.35
#  pliegue_cutaneo_ESCAPULAR      36.87
#  pliegue_cutaneo_SUPRAILIACO    40.53
#  dtype: float64, 'Porciento %')

# %%
#OBTENIENDO EL CUANTIL QUE LE ESPECIFIQUEMOS
Q = datos_nutricion["peso_kg"].quantile([.75])

print("Mínimo:", min(datos_nutricion["peso_kg"].round(2)))
print('Cuantil -->', round(Q, 2))
print("Máximo:", max(datos_nutricion["peso_kg"].round(2)))
# Out:
# Mínimo: 33
# Cuantil --> 0.75    61.0
# Name: peso_kg, dtype: float64
# Máximo: 91

# %%
#OBESERVANDO LA CURTOSIS 
from scipy.stats import kurtosis

def kurtosis_data(x):
  curtosis =  kurtosis(x, fisher=True)

  if curtosis >0:
    return ('Es Leptocúrtica-->', round(curtosis,2 ))
  elif curtosis ==0: # 0.03
    return  ('Es Mesocúrtica-->', round(curtosis,2 ))
  else:
    return  ('Es Platicúrtica-->', round(curtosis,2 ))

# %%
datos_nutricion[var_num].apply(kurtosis_data, axis=0).T
# Out:
#                                               0      1
# talla                        Es Leptocúrtica-->   0.07
# edad                         Es Leptocúrtica-->  57.67
# peso_kg                      Es Leptocúrtica-->   1.47
# circun_cuello                Es Leptocúrtica-->   0.43
# IMC                          Es Leptocúrtica-->   1.78
# circun_cintura               Es Leptocúrtica-->   1.65
# cadera                       Es Leptocúrtica-->   1.27
# ind_cintura_cadera           Es Leptocúrtica-->   0.41
# ind_cintura_estatura         Es Leptocúrtica-->    1.8
# por_grasa_corporal           Es Platicúrtica-->  -1.11
# masa_corporal_magra_kg       Es Leptocúrtica-->   0.41
# pliegue_cutaneo_BICEPS       Es Leptocúrtica-->  62.17
# pliegue_cutaneo_TRICEPS      Es Leptocúrtica-->   0.06
# pliegue_cutaneo_ESCAPULAR    Es Leptocúrtica-->   0.72
# pliegue_cutaneo_SUPRAILIACO  Es Platicúrtica-->  -0.31

# %% [markdown]
# CORRELACIONES "R DE PEARSON" Y "RHO DE SPEARMAN"

# %%
# gráfico de puntos y curvas
plt.figure(figsize=(6,4))

sns.pairplot(datos_nutricion[var_num], diag_kind='kde');

# %%
datos_nutricion.head()
# Out:
#    Individuo  talla  edad  peso_kg  circun_cuello  IMC  circun_cintura  \
# 0  Persona 1    155    16       71             35   29              90
# 1  Persona 2    166    16       61             31   22              80
# 2  Persona 3    151    16       49             30   21              72
# 3  Persona 4    151    16       54             32   23              74
# 4  Persona 5    160    16       58             30   22              74
#
#    cadera  ind_cintura_cadera  ind_cintura_estatura  por_grasa_corporal  \
# 0      98            0.918367              0.578035           36.446202
# 1     100            0.804975              0.485886           28.790714
# 2      86            0.837209              0.475876           29.867419
# 3      88            0.841629              0.490442           27.867640
# 4      97            0.813075              0.470617           30.276688
#
#    masa_corporal_magra_kg  pliegue_cutaneo_BICEPS  pliegue_cutaneo_TRICEPS  \
# ...

# %% [markdown]
# CORRELACION DE PEARSON

# %%
r = datos_nutricion[var_num].corr(method='pearson').round(3) # paramétrico -> X y Y: distribución normal
r
# Out:
#                              talla   edad  peso_kg  circun_cuello    IMC  \
# talla                        1.000  0.090    0.462          0.178 -0.144
# edad                         0.090  1.000    0.140          0.090  0.143
# peso_kg                      0.462  0.140    1.000          0.748  0.745
# circun_cuello                0.178  0.090    0.748          1.000  0.756
# IMC                         -0.144  0.143    0.745          0.756  1.000
# circun_cintura               0.162  0.147    0.774          0.691  0.768
# cadera                       0.029  0.168    0.692          0.498  0.777
# ind_cintura_cadera           0.203  0.012    0.278          0.386  0.162
# ind_cintura_estatura        -0.307  0.108    0.544          0.593  0.824
# por_grasa_corporal          -0.506  0.048    0.202          0.121  0.585
# masa_corporal_magra_kg       0.748  0.107    0.772          0.614  0.312
# pliegue_cutaneo_BICEPS      -0.307 -0.028    0.205          0.140  0.442
# ...

# %%
mask = np.triu(np.ones_like(r, dtype=bool )) #la máscara para el triángulo superior del gráfico
f, ax = plt.subplots(figsize = (10,10)) # la base para el gráfico
g = sns.heatmap(r, mask = mask, cmap='plasma', vmax=1, center = 0, 
            square = True, linewidths=.1, annot=True)

g.set_title("Gráfico Nº XX: Gráfico de la correlación r de pearson")
# Out:
# Text(0.5, 1.0, 'Gráfico Nº XX: Gráfico de la correlación r de pearson')

# %% [markdown]
# CORRELACION RHO DE SPEARMAN

# %%
Rho = datos_nutricion[var_num].corr(method='spearman').round(3) # no paramétrico
Rho
# Out:
#                              talla   edad  peso_kg  circun_cuello    IMC  \
# talla                        1.000  0.089    0.450          0.171 -0.178
# edad                         0.089  1.000    0.129          0.081  0.140
# peso_kg                      0.450  0.129    1.000          0.737  0.701
# circun_cuello                0.171  0.081    0.737          1.000  0.747
# IMC                         -0.178  0.140    0.701          0.747  1.000
# circun_cintura               0.150  0.136    0.765          0.679  0.734
# cadera                      -0.030  0.142    0.636          0.465  0.734
# ind_cintura_cadera           0.233  0.024    0.287          0.369  0.133
# ind_cintura_estatura        -0.347  0.091    0.473          0.555  0.788
# por_grasa_corporal          -0.496  0.060    0.241          0.187  0.639
# masa_corporal_magra_kg       0.741  0.082    0.747          0.603  0.256
# pliegue_cutaneo_BICEPS      -0.420 -0.020    0.197          0.145  0.533
# ...

# %%
mask = np.triu(np.ones_like(Rho, dtype=bool )) #la máscara para el triángulo superior del gráfico
f, ax = plt.subplots(figsize = (10,10)) # la base para el gráfico
g = sns.heatmap(Rho, mask = mask, cmap='viridis', vmax=1, center = 0, 
            square = True, linewidths=.1, annot=True)

g.set_title("Gráfico Nº XX: Gráfico de la correlación Rho de Spearman")
# Out:
# Text(0.5, 1.0, 'Gráfico Nº XX: Gráfico de la correlación Rho de Spearman')
